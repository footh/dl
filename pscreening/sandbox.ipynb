# %%
import util
import matplotlib

matplotlib.rc('animation', html='html5')

util.animate_npy('train/17/80e5fcd38db6f482209881f8b3df839d.npy', show=False)
# Out:
# <video width="504" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
